# %% [markdown]
# # Querying with SQLAlchemy - Lab
#
# ## Introduction
#
# In this lesson, we'll learn how to use SQLAlchemy to write queries about Microsoft's _Northwind Traders_ database!
#
# ## Objectives
#
# You will be able to:
#
# * Read and understand an ERD diagram
# * Create queries with SQLAlchemy, including queries that involve many-to-many relationships
#
# ## Getting Started
#
# In order to complete this lab, we'll need to download a SQLite3-compatible version of the _Northwind Traders_ database from Microsoft.  Microsoft built this database back in the year 2000 to help showcase their SQL Server technology. Since then, it has been open-sourced and has become a great practice tool for every new generation of SQL learners.
#
# Lucky for us, some generous programmers have already converted the Northwind database to a sqlite-compatible version and posted it on Github. We've already included the file the SQL database file that we'll be working with in the repo for this folder, along with the following ERD Diagram. However, if you would like to work with the larger version of this dataset at a future time, just clone [this repo](https://github.com/jpwhite3/northwind-SQLite3) and follow their instructions to access it!
#
# ## ERD Diagram For Northwind Traders
#
# The following ERD Diagram describes the Northwind Traders Database:
#
# <img src='Northwind_ERD.png'>
#
# If the text seems a bit hard to read inside this jupyter notebook, just go into the folder for this repo and open the `Northwind_ERD.png` file manually to see it full size.
#
# ## Connecting to the Database
#
# The first thing we'll need to do is connect to the Northwind Traders database, which can be found in the file `Northwind_small.sqlite`.
#
# In the cell below, import the necessary tools from the `sqlalchemy` library, and take the necessary steps to connect to the database.
#
# **_NOTE:_** We won't be modifying the information in the database at all, just querying it, so there's no need to import the various things you would need to create declarative base classes and the like.

# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker

engine = create_engine("sqlite:///Northwind_small.sqlite",
                      echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Get Table Names and Table Information
#
# One of the most useful things we can do when working with a new database is to inspect the tables until we have a solid idea of what we're looking at.  As you work through this lab, you'll notice that there are some small discrepancies between the Table/Column names listed in the ERD and what they are actually are in the database.  This may be annoying, but this is not an accident--sometimes, documentation is wrong!  By learning how to inspect what tables exist in a database, as well as how which columns exist inside a table, we can save ourselves a lot of headaches by double checking.
#
# In the cell below:
#
# * Import `inspect` from sqlalchemy
# * Create an inspector object by passing in `engine` to `inspect`
# * Use the appropriate inspector function to get the names of all tables

# %%
from sqlalchemy import inspect

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# 2019-04-23 21:02:45,500 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-04-23 21:02:45,502 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:02:45,505 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-04-23 21:02:45,507 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:02:45,510 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-04-23 21:02:45,510 INFO sqlalchemy.engine.base.Engine ()
# ['Category', 'Customer', 'CustomerCustomerDemo', 'CustomerDemographic', 'Employee', 'EmployeeTerritory', 'Order', 'OrderDetail', 'Product', 'Region', 'Shipper', 'Supplier', 'Territory']

# %% [markdown]
# Great! We can now see exactly what each Table is named.
#
# **_Question_**:
#
# Are there any discrepancies between the table names and the ERD diagrams? if so, what are they?
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________
#
#
#
# Let's inspect the column names on one of the tables as well. In the cell below, call the appropriate method to get all column names for the `'Employee'` table.

# %%
inspector.get_columns('Employee')
# Out:
# 2019-04-23 21:02:46,016 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2019-04-23 21:02:46,104 INFO sqlalchemy.engine.base.Engine ()
# [{'name': 'Id',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 1},
#  {'name': 'LastName',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'FirstName',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Title',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'TitleOfCourtesy',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'BirthDate',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'HireDate',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Address',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'City',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Region',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'PostalCode',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Country',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'HomePhone',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Extension',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Photo',
#   'type': BLOB(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'Notes',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'ReportsTo',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'PhotoPath',
#   'type': VARCHAR(length=8000),
#   'nullable': True,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0}]

# %% [markdown]
# That output is good, but its a bit messy. Let's write a function that makes it a bit more readable, and only tells us what we need to know.
#
# The current structure of the output is a list of dictionaries. Complete the function below so that when the function is called and passed a table name, it prints out the name and type of each column in a well-formatted way.

# %%
def get_columns_info(col_name):
    cols_list = inspector.get_columns(col_name)
    
    print("Table Name: {}".format(col_name))
    print("")
    
    for val in cols_list:
        print("Name: {} - Type: {}".format(val['name'], val['type']))

get_columns_info('Employee')
# Out:
# Table Name: Employee
#
# Name: Id - Type: INTEGER
# Name: LastName - Type: VARCHAR(8000)
# Name: FirstName - Type: VARCHAR(8000)
# Name: Title - Type: VARCHAR(8000)
# Name: TitleOfCourtesy - Type: VARCHAR(8000)
# Name: BirthDate - Type: VARCHAR(8000)
# Name: HireDate - Type: VARCHAR(8000)
# Name: Address - Type: VARCHAR(8000)
# Name: City - Type: VARCHAR(8000)
# Name: Region - Type: VARCHAR(8000)
# Name: PostalCode - Type: VARCHAR(8000)
# Name: Country - Type: VARCHAR(8000)
# Name: HomePhone - Type: VARCHAR(8000)
# Name: Extension - Type: VARCHAR(8000)
# Name: Photo - Type: BLOB
# Name: Notes - Type: VARCHAR(8000)
# Name: ReportsTo - Type: INTEGER
# Name: PhotoPath - Type: VARCHAR(8000)

# %% [raw]
# # Expected Output:
#
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)

# %% [markdown]
# ## Connecting and Executing Raw SQL Statements
#
# Sometimes, the easiest thing for us to do is to just execute a raw SQL statement.  This is very easy with SQLAlchemy--we just need to establish a connection, and then use the appropriat methods to execute SQL statements!
#
# In the cell below:
#
# * Create a connection using the `engine` object's appropriate method and store it in the variable `con`
# * Use the appropriate method from `con` to execute a raw SQL statement (in the form of a string) that gets everything from the `'Customer'` table with a LIMIT of 5. Store the results returned in the variable `rs`
# * Use the `fetchall()` method to display all results from `rs`.

# %%
query = """
SELECT 
    *
FROM 
    Customer
LIMIT 5;
"""

con = engine.connect()
rs = con.execute(query)

print(rs.fetchall())
# Out:
# 2019-04-23 21:02:47,693 INFO sqlalchemy.engine.base.Engine
# SELECT
#     *
# FROM
#     Customer
# LIMIT 5;
#
# 2019-04-23 21:02:47,694 INFO sqlalchemy.engine.base.Engine ()
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [raw]
# # Expected Output:
#
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [markdown]
# ## Incorporating Pandas DataFrames
#
# So far we've been able to easily connect to a SQL database, inspect the tables, and execute queries. However, the results returned from queries haven't been in an easily readable format.  We'll fix that by taking the results and storing it in a pandas DataFrame!
#
# In the cell below:
#
# * Import pandas and set the standard alias.
# * Create and execute a query that gets The firstname, lastname, and title of every person in the `'Employee'` table.
# * Create a pandas DataFrame out of the results returned from `rs.fetchall()`
# * Display the head of the new DataFRame

# %%
import pandas as pd

query = """
SELECT
    firstname, lastname, title
FROM
    Employee;"""

rs = con.execute(query)
df = pd.DataFrame(rs.fetchall())
df.head()
# Out:
# 2019-04-23 21:02:49,071 INFO sqlalchemy.engine.base.Engine
# SELECT
#     firstname, lastname, title
# FROM
#     Employee;
# 2019-04-23 21:02:49,072 INFO sqlalchemy.engine.base.Engine ()
#           0          1                      2
# 0     Nancy    Davolio   Sales Representative
# 1    Andrew     Fuller  Vice President, Sales
# 2     Janet  Leverling   Sales Representative
# 3  Margaret    Peacock   Sales Representative
# 4    Steven   Buchanan          Sales Manager

# %% [markdown]
# Nice! We can now read our results.  However, the columns of our DataFrame aren't labeled.  Luckily, pandas plays nicely with the sqlalchemy library, and can actually execute sql queries!

# %% [markdown]
# ### Writing Queries with Pandas
#
# In the cell below:
#
# * Use the appropriate method from pandas to select all columns for every row in the `[Order]` table where the customer is `'VINET'`
# * Be sure to pass in our `engine` as the 2nd parameter, otherwise it won't work!
# * Display the head of the DataFrame created to ensure everything worked correctly.

# %%
df = pd.read_sql_query("SELECT firstname, lastname, title FROM Employee;", engine)
df.head()
# Out:
# 2019-04-23 21:02:54,066 INFO sqlalchemy.engine.base.Engine SELECT firstname, lastname, title FROM Employee;
# 2019-04-23 21:02:54,067 INFO sqlalchemy.engine.base.Engine ()
#   FirstName   LastName                  Title
# 0     Nancy    Davolio   Sales Representative
# 1    Andrew     Fuller  Vice President, Sales
# 2     Janet  Leverling   Sales Representative
# 3  Margaret    Peacock   Sales Representative
# 4    Steven   Buchanan          Sales Manager

# %% [markdown]
# Great! As we can see from the output above, when we let pandas execute the SQL query for us, the DataFrame now contains columns with the correct labels. This is a great way to execute SQL while still making sure our results are easy to read and manipulate by using DataFrames!
#
# ## Executing JOIN Statements
#
# Let's try executing a JOIN statement inside `pd.read_sql_query`.
#
# In the cell below:
#
# * Write a query that gets the Order ID, Company Name, and the total count of orders made by each company (as num_orders).
# * Group the results by Company Name
# * Order the results by num_orders, descending
# * Display the head of the DataFrame to ensure everything worked correctly.

# %%
get_columns_info('Order')
# Out:
# 2019-04-23 21:03:49,286 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2019-04-23 21:03:49,288 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Order
#
# Name: Id - Type: INTEGER
# Name: CustomerId - Type: VARCHAR(8000)
# Name: EmployeeId - Type: INTEGER
# Name: OrderDate - Type: VARCHAR(8000)
# Name: RequiredDate - Type: VARCHAR(8000)
# Name: ShippedDate - Type: VARCHAR(8000)
# Name: ShipVia - Type: INTEGER
# Name: Freight - Type: DECIMAL
# Name: ShipName - Type: VARCHAR(8000)
# Name: ShipAddress - Type: VARCHAR(8000)
# Name: ShipCity - Type: VARCHAR(8000)
# Name: ShipRegion - Type: VARCHAR(8000)
# Name: ShipPostalCode - Type: VARCHAR(8000)
# Name: ShipCountry - Type: VARCHAR(8000)

# %%
get_columns_info('Customer')
# Out:
# 2019-04-23 21:05:55,054 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Customer")
# 2019-04-23 21:05:55,056 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Customer
#
# Name: Id - Type: VARCHAR(8000)
# Name: CompanyName - Type: VARCHAR(8000)
# Name: ContactName - Type: VARCHAR(8000)
# Name: ContactTitle - Type: VARCHAR(8000)
# Name: Address - Type: VARCHAR(8000)
# Name: City - Type: VARCHAR(8000)
# Name: Region - Type: VARCHAR(8000)
# Name: PostalCode - Type: VARCHAR(8000)
# Name: Country - Type: VARCHAR(8000)
# Name: Phone - Type: VARCHAR(8000)
# Name: Fax - Type: VARCHAR(8000)

# %%
query = """
SELECT c.Id
,      c.CompanyName
,      COUNT(*) num_orders
FROM [Order] o
INNER JOIN 
    Customer c
    ON o.CustomerID = c.Id
    GROUP BY c.CompanyName
    ORDER BY num_orders DESC;"""

df = pd.read_sql_query(query, engine)
df.head()
# Out:
# 2019-04-23 21:21:48,228 INFO sqlalchemy.engine.base.Engine
# SELECT c.Id
# ,      c.CompanyName
# ,      COUNT(*) num_orders
# FROM [Order] o
# INNER JOIN
#     Customer c
#     ON o.CustomerID = c.Id
#     GROUP BY c.CompanyName
#     ORDER BY num_orders DESC;
# 2019-04-23 21:21:48,230 INFO sqlalchemy.engine.base.Engine ()
#       Id                   CompanyName  num_orders
# 0  SAVEA            Save-a-lot Markets          31
# 1  ERNSH                  Ernst Handel          30
# 2  QUICK                    QUICK-Stop          28
# 3  FOLKO                Folk och fä HB          19
# 4  HUNGO  Hungry Owl All-Night Grocers          19

# %% [markdown]
# ### Expected Output
#
# <img src='join_results.png'>
#
# Great job! Let's see if we can execute a join that includes entities with a many-to-many relationship.
#
# ### JOINs with Many-To-Many Relationships
#
# In the cell below:
#
# * Write a query that selects the LastName, FirstName and number of territories assigned for every employee.
# * Group the results by employee lastname
# * Order by the total number of territories assigned to each employee, descending
# * You'll need to make use a join table to solve this one--be sure to take a look at the ERD diagram again if needed!
# * Store your results in a DataFrame and display the head to ensure that everything worked correctly.
#
# **_NOTE:_** For long SQL statements, consider using the multiline string format in python, denoted by `"""three quotes"""` at the beginning and end.  Note that if you hit enter to move to another line, be sure to add an `\` character at the end of the line to escape it--otherwise, your sql statements will contain `\n` newline characters wherever you hit enter to move to the next line.

# %%
q = """
SELECT
    e.LastName
,   e.FirstName
,   COUNT(t.ID) TerritoriesAssigned
FROM Territory t
INNER JOIN 
    (SELECT * 
        FROM EmployeeTerritory e1 
    INNER JOIN Employee e2
    ON e1.EmployeeID = e2.Id) e
ON e.TerritoryId = t.Id
GROUP BY e.LastName
ORDER BY TerritoriesAssigned DESC;
"""

df2 = pd.read_sql_query(q, engine)
df2.head()
# Out:
# 2019-04-23 21:31:37,843 INFO sqlalchemy.engine.base.Engine
# SELECT
#     e.LastName
# ,   e.FirstName
# ,   COUNT(t.ID) TerritoriesAssigned
# FROM Territory t
# INNER JOIN
#     (SELECT *
#         FROM EmployeeTerritory e1
#     INNER JOIN Employee e2
#     ON e1.EmployeeID = e2.Id) e
# ON e.TerritoryId = t.Id
# GROUP BY e.LastName
# ORDER BY TerritoriesAssigned DESC;
#
# 2019-04-23 21:31:37,844 INFO sqlalchemy.engine.base.Engine ()
#     LastName FirstName  TerritoriesAssigned
# 0       King    Robert                   10
# 1   Buchanan    Steven                    7
# 2  Dodsworth      Anne                    7
# 3     Fuller    Andrew                    7
# 4     Suyama   Michael                    5

# %% [markdown]
# #### Expected Output:
#
# <img src='many-to-many-results.png'>

# %% [markdown]
# Great job! You've demonstrated proficiency using raw sql with SQLAlchemy. However, we haven't yet touched all the fun declarative stuff.  Let's get some practice working with SQLAlchemy `session` objects below!
#
# ## Using SQLAlchemy Sessions
#
# So far, we've just been using SQLAlchemy as a way to connect to a database and run SQL queries. However, SQLAlchemy is an **_Object-Relational Mapper_**, and can map entities in our database to python objects! This can be incredibly helpful when we need to incorporate data from our database into an object-oriented program or model.
#
# Let's start by getting some practice with `session` objects, because that's where all the magic happens.
#
# ### Using `.query` Objects
#
# Recall that we created a `session` object at the beginning of this lab by using SQLAlchemy's `sessionmaker` function and binding it to our `engine` object.  We haven't used our `session` object too much thus far, but now we'll use it for queries!
#
# The `session` object contains a `.query()` method which returns a query object containing the results of our query, with the results mapped to objects.
#
# Before we can make use of Object-Relational Mappings, we need to make sure that we have mappings created that map the tables in our existing database to objects in python.  We don't want to have to do this manually, so we'll make use the `automap` module inside of `sqlalchemy.ext`.
#
# In the cell below:
#
# * Import `MetaData` from `sqlalchemy`
# * Import `automap_base` from `sqlalchemy.ext.automap`
# * Create a `MetaData` object
# * Use the metadata object's `reflect` method on our `engine`
# * Call `automap_base` and set the `metadata` parameter to our `metadata`. Store the results returned inside of the variable `Base`
# * Call `base.prepare()`
# * Map `Employee` and `Customer` to the `Employee` and `Customer` classes, which can be found inside of `Base.classes`

# %%
from sqlalchemy import MetaData
from sqlalchemy.ext.automap import automap_base

metadata = MetaData()

metadata.reflect(engine)

Base = automap_base(metadata=metadata)
Base.prepare()
# Don't forget to .prepare()!

Employee, Customer = Base.Employee, Base.Customer
# Out:
# 2019-04-23 21:34:38,031 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-04-23 21:34:38,105 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,109 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Category")
# 2019-04-23 21:34:38,110 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,112 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-23 21:34:38,113 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,115 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Category")
# 2019-04-23 21:34:38,116 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,118 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-23 21:34:38,119 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,125 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-04-23 21:34:38,126 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,127 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-04-23 21:34:38,128 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,129 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-04-23 21:34:38,130 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,134 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Customer")
# 2019-04-23 21:34:38,134 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,136 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-23 21:34:38,137 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,138 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Customer")
# 2019-04-23 21:34:38,138 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,139 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-23 21:34:38,140 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,142 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-04-23 21:34:38,143 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,144 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-04-23 21:34:38,146 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,147 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Customer_1")
# 2019-04-23 21:34:38,148 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,149 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-04-23 21:34:38,150 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,152 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerCustomerDemo")
# 2019-04-23 21:34:38,153 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,154 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-23 21:34:38,155 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,157 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerCustomerDemo")
# 2019-04-23 21:34:38,158 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,159 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-23 21:34:38,160 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,162 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-04-23 21:34:38,162 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,164 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-04-23 21:34:38,164 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,166 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerCustomerDemo_1")
# 2019-04-23 21:34:38,167 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,168 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-04-23 21:34:38,169 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,171 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerDemographic")
# 2019-04-23 21:34:38,172 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,173 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-23 21:34:38,174 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,175 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerDemographic")
# 2019-04-23 21:34:38,176 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,177 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-23 21:34:38,178 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,179 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-04-23 21:34:38,179 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,180 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-04-23 21:34:38,181 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,182 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerDemographic_1")
# 2019-04-23 21:34:38,183 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,184 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-04-23 21:34:38,185 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,186 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2019-04-23 21:34:38,186 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,188 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-23 21:34:38,189 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,190 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Employee")
# 2019-04-23 21:34:38,191 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,191 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-23 21:34:38,192 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,193 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-04-23 21:34:38,193 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,195 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-04-23 21:34:38,196 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,197 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-04-23 21:34:38,197 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,199 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("EmployeeTerritory")
# 2019-04-23 21:34:38,199 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,200 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-23 21:34:38,201 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,203 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("EmployeeTerritory")
# 2019-04-23 21:34:38,204 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,205 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-23 21:34:38,206 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,207 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-04-23 21:34:38,207 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,208 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-04-23 21:34:38,209 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,210 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_EmployeeTerritory_1")
# 2019-04-23 21:34:38,210 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,211 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-04-23 21:34:38,212 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,213 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2019-04-23 21:34:38,215 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,217 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-23 21:34:38,218 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,220 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Order")
# 2019-04-23 21:34:38,220 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,221 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-23 21:34:38,222 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,223 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-04-23 21:34:38,223 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,224 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-04-23 21:34:38,225 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,226 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-04-23 21:34:38,226 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,227 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("OrderDetail")
# 2019-04-23 21:34:38,228 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,230 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-23 21:34:38,231 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,232 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("OrderDetail")
# 2019-04-23 21:34:38,233 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,234 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-23 21:34:38,234 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,236 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-04-23 21:34:38,238 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,240 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-04-23 21:34:38,240 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,242 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_OrderDetail_1")
# 2019-04-23 21:34:38,243 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,244 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-04-23 21:34:38,244 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,245 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Product")
# 2019-04-23 21:34:38,246 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,247 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-23 21:34:38,247 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,248 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Product")
# 2019-04-23 21:34:38,249 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,250 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-23 21:34:38,250 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,251 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-04-23 21:34:38,251 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,252 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-04-23 21:34:38,253 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,253 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-04-23 21:34:38,254 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,255 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Region")
# 2019-04-23 21:34:38,256 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,257 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-23 21:34:38,258 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,260 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Region")
# 2019-04-23 21:34:38,261 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,262 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-23 21:34:38,263 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,264 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-04-23 21:34:38,264 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,265 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-04-23 21:34:38,265 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,266 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-04-23 21:34:38,266 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,268 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Shipper")
# 2019-04-23 21:34:38,268 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,269 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-23 21:34:38,269 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,270 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Shipper")
# 2019-04-23 21:34:38,271 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,272 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-23 21:34:38,272 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,273 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-04-23 21:34:38,273 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,274 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-04-23 21:34:38,274 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,275 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-04-23 21:34:38,276 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,277 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Supplier")
# 2019-04-23 21:34:38,277 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,279 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-23 21:34:38,279 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,280 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Supplier")
# 2019-04-23 21:34:38,281 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,281 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-23 21:34:38,282 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,283 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-04-23 21:34:38,283 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,284 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-04-23 21:34:38,284 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,285 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-04-23 21:34:38,286 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,287 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Territory")
# 2019-04-23 21:34:38,287 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,288 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-23 21:34:38,289 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,290 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Territory")
# 2019-04-23 21:34:38,290 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,291 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-23 21:34:38,291 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,292 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-04-23 21:34:38,293 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,293 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-04-23 21:34:38,294 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,295 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Territory_1")
# 2019-04-23 21:34:38,295 INFO sqlalchemy.engine.base.Engine ()
# 2019-04-23 21:34:38,296 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-04-23 21:34:38,297 INFO sqlalchemy.engine.base.Engine ()
# AttributeErrorTraceback (most recent call last)
# <ipython-input-33-1af731aa3fc0> in <module>()
#      10 # Don't forget to .prepare()!
#      11
# ---> 12 Employee, Customer = Base.Employee, Base.Customer
#
# AttributeError: type object 'Base' has no attribute 'Employee'

# %% [markdown]
# Now that we have some mappings set up, we can make use of `session.query()` help us query our database!
#
# ### Writing Basic Queries
#
# Let's use the `query()` object to get all the employees from the `'Employee'` table.
#
# In the cell below:
#
# * Create a for loop that iterates through the results returned by a `session.query()` of the Employee table (pass this as a variable, not a string).
# * Order the results by the Employee's `.HireDate` attribute.
# * Print the last name, first name, and hire date of each employee.

# %%
for instance in session.query(Customer):
    print(instance.CustomerName)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-34-14a0bee182aa> in <module>()
# ----> 1 for instance in session.query(Customer):
#       2     print(instance.CustomerName)
#
# NameError: name 'Customer' is not defined

# %% [markdown]
# ### Implicit JOINs using `.filter()`
#
# One great benefit of using `session.query()` to query our data is that we can easily execute **_implicit joins_** by making use of the `.filter()` method.
#
# So far we've only explicitly specified mappings for the `Employee` and `Customer` classes.  We'll need to do this now for the `Product` and `Category` classes before we can use them with `session.query()`.
#
# In the cell below, set the mappings for `Product` and `Category`.
#
# **_HINT:_** This will look just like the last line of the code cell where we declared our mappings previously.  No need to repeat all the steps for getting metadata and creating a `Base` class. Just set the mappings!

# %%
Product, Category = None, None

# %% [markdown]
# Great!
#
# Now, in the cell below:
#
# * Create a for loop that iterates through all results returned from a query of Products and Categories
# * Use the `.filter()` method to only include cases where the Product's `.CategoryID` matches the Category's `.Id` attribute.
# * Print out the name of each product, followed by the name of the category that it belongs to.

# %% [markdown]
# ## Summary
#
# Great job! You've just used SQLAlchemy to work with a sample production database. Note that there are many, many more awesome things that SQLAlchemy can do, but they're outside the scope of this lesson.  However, if you're interested in learning more, don't be afraid to take a look at the [SQLAlchemy documentation](https://docs.sqlalchemy.org/en/latest/orm/tutorial.html) and work through some tutorials in your spare time!
